# %%
import torch
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, random_split
from torch import nn, optim
from tqdm import tqdm
import os
import numpy as np
from sklearn.metrics import confusion_matrix
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_curve, auc, confusion_matrix, roc_auc_score
import torchvision.models as models

# %%
# Define your parameters
img_height, img_width = 256, 256
batch_size = 1

dataset_dirs = [
    
'F:/Anonymized/EDI/DP_Pix/Gender_Classification/Iteration_44',
'F:/Anonymized/EDI/Pixel_Masked/Gender_Classification/Iteration_36/'
    
    
    
    
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_0',
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_1',
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_2',
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_3',
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_4',
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_5',
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_6',
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_7',
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_8',
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_9',
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_10',
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_11',
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_12',
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_13',
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_14',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_15',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_16',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_17',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_18',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_19',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_20',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_21',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_22',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_23',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_24',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_25',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_26',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_27',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_28',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_29',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_30',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_31',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_32',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_33',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_34',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_35',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_36',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_37',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_38',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_39',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_40',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_41',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_42',
#      'F:/Anonymized/EDI/Blur_BKS_10/Gender_Classification/Iteration_43',
#      'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_44'
    
    
#                 'F:/Anonymized/Original/Mouth_Masked/Gender_Classification',
#                 'F:/Anonymized/Original/Eyes_Masked/Gender_Classification',
# #                 'F:/Anonymized/Original/Blur/BKS_100/Gender_Classification',
                
#                 'F:/Anonymized/EDI/Pixel_Masked_99.9/Gender_Classification/Iteration_0/',
#                 'F:/Anonymized/EDI/Pixel_Masked_99.9/Gender_Classification/Iteration_1/',
#                 'F:/Anonymized/EDI/Pixel_Masked_99.9/Gender_Classification/Iteration_2/',
#                 'F:/Anonymized/EDI/Pixel_Masked_99.9/Gender_Classification/Iteration_3/',
#                 'F:/Anonymized/EDI/Pixel_Masked_99.9/Gender_Classification/Iteration_4/',
    
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_5/',
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_6/',
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_7/',
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_8/',
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_9/',
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_10/',
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_11/',
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_12/',
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_13/',
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_14/',
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_15/',
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_16/',
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_17/',
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_18/',
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_19/',
#                 'F:/Anonymized/EDI/Blur/Gender_Classification/Iteration_20/'
    
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_12/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_13/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_14/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_15/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_16/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_17/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_18/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_19/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_20/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_21/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_22/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_23/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_24/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_25/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_26/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_27/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_28/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_29/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_30/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_31/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_32/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_33/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_34/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_35/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_36/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_37/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_38/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_39/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_40/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_41/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_42/',
#                 'F:/Anonymized/EDI/DP_Blur/Gender_Classification/Iteration_43/'

]

classes = ['Females', 'Males']
num_classes = 2

# %%
# # Define transform
transform = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
model = models.convnext_base(pretrained=True)
model.classifier[2]=nn.Linear(1024,num_classes)

model.load_state_dict(torch.load('gender_classification_convnext_pretrained.pt'))
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.001)
# Out:
# C:\Users\012709558\AppData\Local\anaconda3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\012709558\AppData\Local\anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ConvNeXt_Base_Weights.IMAGENET1K_V1`. You can also use `weights=ConvNeXt_Base_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# def save_roc_plot(fpr, tpr, auc, dataset_dir, ROC_dir):
#     path_components = os.path.normpath(dataset_dir).split(os.path.sep)
#     dataset_name = os.path.join(*path_components[-3:])
#     dataset_name = dataset_name.replace(os.path.sep, '_')
#     plt.figure()
#     plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {auc:.2f})')
#     plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
#     plt.xlim([0.0, 1.0])
#     plt.ylim([0.0, 1.05])
#     plt.xlabel('False Positive Rate')
#     plt.ylabel('True Positive Rate')
#     plt.title(f'ROC Curve')
#     plt.legend(loc='lower right')
#     plt.savefig(os.path.join(ROC_dir, f'ROC_{dataset_name}.png'))
#     plt.close()

# %%
def evaluate_model(model, test_loader, dataset_name):
    model.eval()  # Set the model to evaluation mode

    y_true = []
    y_pred = []

    with torch.no_grad():
        for inputs, targets in tqdm(test_loader):
            inputs = inputs.to(device)
            targets = targets.to(device)

            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)

            y_true.extend(targets.cpu().tolist())  # Extend the y_true list
            y_pred.extend(predicted.cpu().tolist())  # Extend the y_pred list

    accuracy = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average='macro')
    precision = precision_score(y_true, y_pred, average='macro')
    recall = recall_score(y_true, y_pred, average='macro')

    class_f1_scores = {}
    for i, class_name in enumerate(test_loader.dataset.classes):
        class_f1 = f1_score(y_true, y_pred, average='macro', labels=[i])
        class_f1_scores[class_name] = class_f1

    return accuracy, f1, precision, recall, class_f1_scores

# %%
# Create a combined result DataFrame for all the datasets
combined_result_df = pd.DataFrame(columns=['Dataset', 'Accuracy', 'F1 Score', 'Precision', 'Recall'])

class_f1_scores = {}

for dataset_dir in dataset_dirs:
    test_dataset = ImageFolder(root=dataset_dir, transform=transform)
    test_loader = DataLoader(test_dataset, batch_size=1, shuffle=True, pin_memory=True)

    path_components = os.path.normpath(dataset_dir).split(os.path.sep)
    dataset_name = os.path.join(*path_components[-3:])
    dataset_name = dataset_name.replace(os.path.sep, '_')

    accuracy, f1, precision, recall, individual_class_f1_scores = evaluate_model(model, test_loader, dataset_name)

    # Append the dataset results to the combined result DataFrame
    combined_result_df = combined_result_df.append({'Dataset': dataset_name,
                                                    'Accuracy': accuracy,
                                                    'F1 Score': f1,
                                                    'Precision': precision,
                                                    'Recall': recall},
                                                   ignore_index=True)

    # Append the class F1 scores to the dictionary
    class_f1_scores[dataset_name] = individual_class_f1_scores
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 3662/3662 [01:49<00:00, 33.54it/s]
# C:\Users\012709558\AppData\Local\Temp\ipykernel_9564\1829439004.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_result_df = combined_result_df.append({'Dataset': dataset_name,
# 100%|██████████████████████████████████████████████████████████████████████████████| 3662/3662 [01:44<00:00, 35.21it/s]
# C:\Users\012709558\AppData\Local\Temp\ipykernel_9564\1829439004.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_result_df = combined_result_df.append({'Dataset': dataset_name,

# %%
# Save the combined result DataFrame to a text file
combined_result_file_path = 'F:/Results_Final/Txt Files/Gender_Final.txt'

# Append individual F1 scores to the text file
with open(combined_result_file_path, 'a') as file:
    for dataset_name, f1_scores_dict in class_f1_scores.items():
        file.write("\nCombined Results:\n")
        file.write("--------------------------------------\n")
        file.write("Dataset\t\t\t\t\t\tAccuracy\t\tF1 Score\tPrecision\t\tRecall\n")
        file.write("--------------------------------------\n")

        dataset_results = combined_result_df[combined_result_df['Dataset'] == dataset_name]
        for index, row in dataset_results.iterrows():
            file.write(f"{row['Dataset']}\t{row['Accuracy']}\t{row['F1 Score']}\t{row['Precision']}\t{row['Recall']}\n")

        file.write("\nIndividual F1 Scores:\n")
        file.write("--------------------------------------\n")

        for class_name, class_f1 in f1_scores_dict.items():
            file.write(f"{class_name}: {class_f1}\n")

        file.write("\n--------------------------------------\n")

# Print message after processing all the datasets
print('Evaluation complete. Combined results and individual F1 scores saved in:', combined_result_file_path)
# Out:
# Evaluation complete. Combined results and individual F1 scores saved in: F:/Results_Final/Txt Files/Gender_Final.txt
